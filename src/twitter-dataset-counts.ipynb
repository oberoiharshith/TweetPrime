# %%
import json
import pandas as pd

# %%
# report counts for corona-out-2

lines=0
tweets = {}
retweets_list = []
quoted_tweets_list = []
geo = 0
urls = 0
hashtags = 0
users = {}
all_users = []

with open("C://Users//sofia//OneDrive//Documents//Rutgers//DatabaseManagement//Project//code//corona-out-2", "r") as f1:
    for line in f1:
        if line != '\n':
            data = json.loads(line)
            lines = lines + 1

            if 'retweeted_status' in data.keys():
                retweets_list.append(data['id_str'])
                tweets[data['retweeted_status']['id_str']] = data['retweeted_status']
            
            if 'quoted_status' in data.keys():
                quoted_tweets_list.append(data['id_str'])
                tweets[data['quoted_status']['id_str']] = data['quoted_status']
            
            tweets[data['id_str']] = data

df_tweets = pd.DataFrame({'tweet':tweets.keys(), 'tweeted':1}).drop_duplicates()
df_tweets['retweeted'] = df_tweets.tweet.isin(retweets_list)*1
df_tweets['quoted'] = df_tweets.tweet.isin(quoted_tweets_list)*1

for i in tweets:
    all_users.append(tweets[i]['user']['id_str'])
    urls += min(len(tweets[i]['entities']['urls']),1)
    hashtags += min(len(tweets[i]['entities']['hashtags']),1)
    if tweets[i]['coordinates'] is not None:
        geo += 1
    if (tweets[i]['user']['id_str'] not in users):
        users[tweets[i]['user']['id_str']] = tweets[i]['user']
    
print('number of unique tweets/retweets/quoted:', df_tweets.shape[0], len(tweets))
print('number of unique tweets:',df_tweets[(df_tweets.retweeted == 0) & (df_tweets.quoted == 0)].shape[0])
print('number of unique retweets:', df_tweets.retweeted.sum())
print('number of unique quoted tweets:', df_tweets.quoted.sum() - df_tweets[(df_tweets.retweeted == 1) & (df_tweets.quoted == 1)].quoted.sum())
print('num of unique users=',len(users))
print('num of tweets with geo=',geo)
print('num of tweets with urls=',urls)
print('num of tweets with hashtags=',hashtags)
# Out:
# number of unique tweets/retweets/quoted: 23157 23157
# number of unique tweets: 10538
# number of unique retweets: 11154
# number of unique quoted tweets: 1465
# num of unique users= 19232
# num of tweets with geo= 14
# num of tweets with urls= 7715
# num of tweets with hashtags= 3673

# %%
# report counts for corona-out-3

lines=0
tweets = {}
tweets_list = []
retweets_list = []
quoted_tweets_list = []
geo = 0
urls = 0
hashtags = 0
users = {}

with open("C://Users//sofia//OneDrive//Documents//Rutgers//DatabaseManagement//Project//code//corona-out-3", "r") as f1:
    for line in f1:
        if line != '\n':
            data = json.loads(line)
            lines = lines + 1

            if 'retweeted_status' in data.keys():
                retweets_list.append(data['id_str'])
                tweets[data['retweeted_status']['id_str']] = data['retweeted_status']
            
            if 'quoted_status' in data.keys():
                quoted_tweets_list.append(data['id_str'])
                tweets[data['quoted_status']['id_str']] = data['quoted_status']
            
            tweets[data['id_str']] = data

df_tweets = pd.DataFrame({'tweet':tweets.keys(), 'tweeted':1}).drop_duplicates()
df_tweets['retweeted'] = df_tweets.tweet.isin(retweets_list)*1
df_tweets['quoted'] = df_tweets.tweet.isin(quoted_tweets_list)*1

for i in tweets:
    all_users.append(tweets[i]['user']['id_str'])
    urls += min(len(tweets[i]['entities']['urls']),1)
    hashtags += min(len(tweets[i]['entities']['hashtags']),1)
    if tweets[i]['coordinates'] is not None:
        geo += 1
    if (tweets[i]['user']['id_str'] not in users):
        users[tweets[i]['user']['id_str']] = tweets[i]['user']
    
print('number of unique tweets/retweets/quoted:', df_tweets.shape[0], len(tweets))
print('number of unique tweets:',df_tweets[(df_tweets.retweeted == 0) & (df_tweets.quoted == 0)].shape[0])
print('number of unique retweets:', df_tweets.retweeted.sum())
print('number of unique quoted tweets:', df_tweets.quoted.sum() - df_tweets[(df_tweets.retweeted == 1) & (df_tweets.quoted == 1)].quoted.sum())
print('num of unique users=',len(users))
print('num of tweets with geo=',geo)
print('num of tweets with urls=',urls)
print('num of tweets with hashtags=',hashtags)
# Out:
# number of unique tweets/retweets/quoted: 115481 115481
# number of unique tweets: 46574
# number of unique retweets: 61090
# number of unique quoted tweets: 7817
# num of unique users= 90336
# num of tweets with geo= 86
# num of tweets with urls= 41597
# num of tweets with hashtags= 24196

# %%
# report counts for combined corona-out-2 and corona-out-3

lines=0
tweets = {}
tweets_list = []
retweets_list = []
quoted_tweets_list = []
geo = 0
urls = 0
hashtags = 0
users = {}

with open("C://Users//sofia//OneDrive//Documents//Rutgers//DatabaseManagement//Project//code//corona-out-2", "r") as f1:
    for line in f1:
        if line != '\n':
            data = json.loads(line)
            lines = lines + 1

            if 'retweeted_status' in data.keys():
                retweets_list.append(data['id_str'])
                tweets[data['retweeted_status']['id_str']] = data['retweeted_status']
            
            if 'quoted_status' in data.keys():
                quoted_tweets_list.append(data['id_str'])
                tweets[data['quoted_status']['id_str']] = data['quoted_status']
            
            tweets[data['id_str']] = data

with open("C://Users//sofia//OneDrive//Documents//Rutgers//DatabaseManagement//Project//code//corona-out-3", "r") as f1:
    for line in f1:
        if line != '\n':
            data = json.loads(line)
            lines = lines + 1

            if 'retweeted_status' in data.keys():
                retweets_list.append(data['id_str'])
                tweets[data['retweeted_status']['id_str']] = data['retweeted_status']
            
            if 'quoted_status' in data.keys():
                quoted_tweets_list.append(data['id_str'])
                tweets[data['quoted_status']['id_str']] = data['quoted_status']
            
            tweets[data['id_str']] = data

df_tweets = pd.DataFrame({'tweet':tweets.keys(), 'tweeted':1}).drop_duplicates()
df_tweets['retweeted'] = df_tweets.tweet.isin(retweets_list)*1
df_tweets['quoted'] = df_tweets.tweet.isin(quoted_tweets_list)*1

for i in tweets:
    all_users.append(tweets[i]['user']['id_str'])
    urls += min(len(tweets[i]['entities']['urls']),1)
    hashtags += min(len(tweets[i]['entities']['hashtags']),1)
    if tweets[i]['coordinates'] is not None:
        geo += 1
    if (tweets[i]['user']['id_str'] not in users):
        users[tweets[i]['user']['id_str']] = tweets[i]['user']
    
print('number of unique tweets/retweets/quoted:', df_tweets.shape[0], len(tweets))
print('number of unique tweets:',df_tweets[(df_tweets.retweeted == 0) & (df_tweets.quoted == 0)].shape[0])
print('number of unique retweets:', df_tweets.retweeted.sum())
print('number of unique quoted tweets:', df_tweets.quoted.sum() - df_tweets[(df_tweets.retweeted == 1) & (df_tweets.quoted == 1)].quoted.sum())
print('num of unique users=',len(users))
print('num of tweets with geo=',geo)
print('num of tweets with urls=',urls)
print('num of tweets with hashtags=',hashtags)
# Out:
# number of unique tweets/retweets/quoted: 138601 138601
# number of unique tweets: 57075
# number of unique retweets: 72244
# number of unique quoted tweets: 9282
# num of unique users= 108043
# num of tweets with geo= 100
# num of tweets with urls= 49292
# num of tweets with hashtags= 27860
